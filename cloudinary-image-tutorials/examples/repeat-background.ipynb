# %%
from dotenv import load_dotenv
import os
import cloudinary
from cloudinary import CloudinaryImage

load_dotenv()

cloudinary.config( 
  cloud_name = os.getenv("CLOUD_NAME"), 
  api_key = os.getenv("API_KEY"), 
  api_secret = os.getenv("API_SECRET")
)

# %%
CloudinaryImage("https://res.cloudinary.com/dg8xfchav/image/upload/v1765108610/bird-on-road.jpg").image(transformation=[
  {'overlay': "cloudinary_icon_white"},
  {'width': 200, 'crop': "scale"},
  {'opacity': 30},
  {'flags': ["layer_apply", "tiled"]}
  ])
# Out:
# '<img src="https://res.cloudinary.com/dg8xfchav/image/upload/v1765108610/bird-on-road.jpg"/>'
